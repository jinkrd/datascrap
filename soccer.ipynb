# %%
import pandas as pd
data_frame=pd.read_csv('WorldCupMatches.csv')
data_frame.shape
# Out:
# (4572, 20)

# %%
data_frame.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
import pandas as pd
data_frame1=pd.DataFrame(data_frame,columns=['Home Team','Away Team','City'])
data_frame1
# Out:
#       Home Team  Away Team         City
# 0           NaN        NaN  Montevideo
# 1           NaN        NaN  Montevideo
# 2           NaN        NaN  Montevideo
# 3           NaN        NaN  Montevideo
# 4           NaN        NaN  Montevideo
# ...         ...        ...          ...
# 4567        NaN        NaN          NaN
# 4568        NaN        NaN          NaN
# 4569        NaN        NaN          NaN
# 4570        NaN        NaN          NaN
# 4571        NaN        NaN          NaN
#
# [4572 rows x 3 columns]

# %%
import pandas as pd
data_frame1=pd.DataFrame(data_frame,columns=['Home Team','Away Team','City'])
data_frame1
# Out:
#       Home Team  Away Team         City
# 0           NaN        NaN  Montevideo
# 1           NaN        NaN  Montevideo
# 2           NaN        NaN  Montevideo
# 3           NaN        NaN  Montevideo
# 4           NaN        NaN  Montevideo
# ...         ...        ...          ...
# 4567        NaN        NaN          NaN
# 4568        NaN        NaN          NaN
# 4569        NaN        NaN          NaN
# 4570        NaN        NaN          NaN
# 4571        NaN        NaN          NaN
#
# [4572 rows x 3 columns]

# %%
import pandas as pd
data_frame=pd.read_csv('WorldCupMatches.csv')
data_frame1=pd.DataFrame(data_frame,columns=['Home Team','Away Team','City'])
data_frame1
# Out:
#       Home Team  Away Team         City
# 0           NaN        NaN  Montevideo
# 1           NaN        NaN  Montevideo
# 2           NaN        NaN  Montevideo
# 3           NaN        NaN  Montevideo
# 4           NaN        NaN  Montevideo
# ...         ...        ...          ...
# 4567        NaN        NaN          NaN
# 4568        NaN        NaN          NaN
# 4569        NaN        NaN          NaN
# 4570        NaN        NaN          NaN
# 4571        NaN        NaN          NaN
#
# [4572 rows x 3 columns]

# %%
import pandas as pd
data_frame=pd.read_csv('WorldCups.csv')
data_frame1=pd.DataFrame(data_frame,columns=['Year','Winner','GoalsScored'])
data_frame1['difference']=data_frame1['']
# Out:
#     Year      Winner  GoalsScored
# 0   1930     Uruguay           70
# 1   1934       Italy           70
# 2   1938       Italy           84
# 3   1950     Uruguay           88
# 4   1954  Germany FR          140
# 5   1958      Brazil          126
# 6   1962      Brazil           89
# 7   1966     England           89
# 8   1970      Brazil           95
# 9   1974  Germany FR           97
# 10  1978   Argentina          102
# 11  1982       Italy          146
# 12  1986   Argentina          132
# 13  1990  Germany FR          115
# 14  1994      Brazil          141
# 15  1998      France          171
# 16  2002      Brazil          161
# 17  2006       Italy          147
# 18  2010       Spain          145
# 19  2014     Germany          171

# %%
import pandas as pd
data_frame=pd.read_csv('WorldCups.csv')
data_frame1=pd.DataFrame(data_frame,columns=['Year','Winner','GoalsScored'])
data_frame1
# Out:
#     Year      Winner  GoalsScored
# 0   1930     Uruguay           70
# 1   1934       Italy           70
# 2   1938       Italy           84
# 3   1950     Uruguay           88
# 4   1954  Germany FR          140
# 5   1958      Brazil          126
# 6   1962      Brazil           89
# 7   1966     England           89
# 8   1970      Brazil           95
# 9   1974  Germany FR           97
# 10  1978   Argentina          102
# 11  1982       Italy          146
# 12  1986   Argentina          132
# 13  1990  Germany FR          115
# 14  1994      Brazil          141
# 15  1998      France          171
# 16  2002      Brazil          161
# 17  2006       Italy          147
# 18  2010       Spain          145
# 19  2014     Germany          171

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x='Year',y='GoalsScored',data=data_frame1)
graph
# Out:
# <AxesSubplot:xlabel='Year', ylabel='GoalsScored'>

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool

TOOLTIPS = HoverTool(tooltips=[
    ("index","$index"),
    ("(Year,GoalsScored)","(@Year,@GoalsScored)"),
    ("Winner","@Winner")]
)
p=figure(title="soccer",x_axis_label='Year',y_axis_label='GoalsScored',plot_width=200,plot_height=500,tools=[TOOLTIPS])
p.circle('Year','GoalsScored',size=10,source=data_frame1)
show(p)

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool

p=figure(title="Soccer",x_axis_label='Year',y_axis_label='GoalsScored',plot_width=500,plot_height=500,tools=[])
p.circle('Year','GoalsScored',size=10,source=data_frame1)
show(p)
